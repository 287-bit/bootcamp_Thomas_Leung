# %% [markdown]
# # Homework Starter — Stage 08 EDA
#
# Fill in the marked TODOs. This notebook generates synthetic data so you can focus on the EDA flow. Replace with your dataset when ready.

# %%
# --- packages this notebook needs (uncomment and run once, then re-comment) ---
# !pip install numpy
# !pip install scipy
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
# !pip install --upgrade pandas   # if an older pandas is already installed
# Out:
# Requirement already satisfied: numpy in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (2.2.6)
# Requirement already satisfied: scipy in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from scipy) (2.2.6)
# Requirement already satisfied: pandas in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: seaborn in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from pandas>=1.2->seaborn) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: matplotlib in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\leung\miniconda3\envs\bootcamp_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from scipy.stats import skew, kurtosis
sns.set(context='talk', style='whitegrid')
np.random.seed(8)
pd.set_option('display.max_columns', 100)

# === Synthetic data generator (adapt or replace with your own data) ===
n = 160
df = pd.DataFrame({
    'date': pd.date_range('2021-02-01', periods=n, freq='D'),
    'region': np.random.choice(['North','South','East','West'], size=n),
    'age': np.random.normal(40, 8, size=n).clip(22, 70).round(1),
    'income': np.random.lognormal(mean=10.6, sigma=0.3, size=n).round(2),
    'transactions': np.random.poisson(lam=3, size=n),
})
base = df['income'] * 0.0015 + df['transactions']*18 + np.random.normal(0, 40, size=n)
df['spend'] = np.maximum(0, base).round(2)

# inject a bit of missingness and outliers
df.loc[np.random.choice(df.index, 5, replace=False), 'income'] = np.nan
df.loc[np.random.choice(df.index, 3, replace=False), 'spend'] = np.nan
df.loc[np.random.choice(df.index, 2, replace=False), 'transactions'] = df['transactions'].max()+12
df
# Out:
#           date region   age    income  transactions   spend
# 0   2021-02-01   West  37.6  28086.81             4   73.35
# 1   2021-02-02  North  43.0  33034.75             1   52.37
# 2   2021-02-03  South  38.2  50045.39             2  131.85
# 3   2021-02-04  South  24.9  39467.28             4  147.58
# 4   2021-02-05  South  59.8  31201.65             1   86.76
# ..         ...    ...   ...       ...           ...     ...
# 155 2021-07-06  South  39.3  57863.60            20  136.87
# 156 2021-07-07   East  41.4  43912.51             5  116.26
# 157 2021-07-08   East  30.9  53308.27             2  134.47
# 158 2021-07-09   East  34.8  28731.93             2   82.64
# 159 2021-07-10   West  44.7  62816.06             3  118.15
#
# [160 rows x 6 columns]

# %% [markdown]
# ## 1) First look

# %%
df.info(), df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          160 non-null    datetime64[ns]
#  1   region        160 non-null    object
#  2   age           160 non-null    float64
#  3   income        155 non-null    float64
#  4   transactions  160 non-null    int32
#  5   spend         157 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int32(1), object(1)
# memory usage: 7.0+ KB
# (None,
#  date            0
#  region          0
#  age             0
#  income          5
#  transactions    0
#  spend           3
#  dtype: int64)

# %% [markdown]
# ## 2) Numeric profile

# %%
desc = df[['age','income','transactions','spend']].describe().T
desc['skew'] = [skew(df[c].dropna()) for c in desc.index]
desc['kurtosis'] = [kurtosis(df[c].dropna()) for c in desc.index]
desc
# Out:
#               count          mean           std       min       25%       50%  \
# age           160.0     40.018750      8.458676     22.00     34.70     40.15
# income        155.0  41983.866323  13262.457038  17928.80  32471.53  39332.52
# transactions  160.0      3.237500      2.585610      0.00      2.00      3.00
# spend         157.0    117.291592     51.768645      0.54     77.25    119.32
#
#                     75%       max      skew   kurtosis
# age              44.925     61.10  0.069538  -0.080125
# income        49697.690  87052.40  0.993336   0.918722
# transactions      4.000     20.00  3.466078  19.984802
# spend           153.340    280.05  0.130860  -0.084917

# %% [markdown]
# ## 2b) Categorical profile
#
# `.describe()` above covers the **numeric** columns only. Every non-numeric column needs
# its own look: how many distinct values it has, how lopsided the split is, and whether one
# category dominates so heavily that it will be useless as a feature.
#
# `region` is the categorical column in this synthetic set. Your own dataset may have
# several — profile all of them.

# %%
# TODO: value counts for every non-numeric column.
#   Hint: df.select_dtypes(exclude='number').columns gives you the list.
#   Print counts AND proportions — a raw count hides how lopsided a split is.

# TODO: plot one of them with sns.countplot (the lecture uses this in section 3).


numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

for i in numeric_cols:
    print(pd.concat([df[i].value_counts(), df[i].value_counts(normalize=True)], axis=1))


fig, ax = plt.subplots(figsize=(12,8))
sns.countplot(x=df['region'],ax =ax )
plt.show()
# Out:
#       count  proportion
# age
# 43.0      4     0.02500
# 22.0      4     0.02500
# 47.4      3     0.01875
# 42.9      3     0.01875
# 35.4      3     0.01875
# ...     ...         ...
# 46.1      1     0.00625
# 39.3      1     0.00625
# 41.4      1     0.00625
# 30.9      1     0.00625
# 34.8      1     0.00625
#
# [122 rows x 2 columns]
#           count  proportion
# income
# 28086.81      1    0.006452
# 33034.75      1    0.006452
# 50045.39      1    0.006452
# 39467.28      1    0.006452
# 31201.65      1    0.006452
# ...         ...         ...
# 57863.60      1    0.006452
# 43912.51      1    0.006452
# 53308.27      1    0.006452
# 28731.93      1    0.006452
# 62816.06      1    0.006452
#
# [155 rows x 2 columns]
#               count  proportion
# transactions
# 2                34     0.21250
# 3                32     0.20000
# 4                29     0.18125
# 1                22     0.13750
# 5                19     0.11875
# 0                10     0.06250
# 6                 6     0.03750
# 7                 3     0.01875
# 8                 3     0.01875
# 20                2     0.01250
#         count  proportion
# spend
# 118.15      2    0.012739
# 73.35       1    0.006369
# 131.85      1    0.006369
# 52.37       1    0.006369
# 86.76       1    0.006369
# ...       ...         ...
# 96.19       1    0.006369
# 136.87      1    0.006369
# 116.26      1    0.006369
# 134.47      1    0.006369
# 82.64       1    0.006369
#
# [156 rows x 2 columns]

# %% [markdown]
# ## 3) Distributions — two worked examples below; add at least one more

# %%
# Example 1 of 2 — histogram + KDE. Keep it, or swap in a column of your own.
sns.histplot(df['income'], kde=True)
plt.title('Income Distribution')
plt.show()

# Example 2 of 2 — boxplot, to expose outliers.
#
# TODO: add ONE more distribution below, on a column of your choosing (3 are required).
sns.boxplot(x=df['transactions'])
plt.title('Transactions (Outliers)')
plt.show()



sns.countplot(x=df['region'] )
plt.title('Region Distribution')
plt.show()

# %% [markdown]
# ## 4) Relationships — both are worked below; swap in your own columns

# %%
sns.scatterplot(data=df, x='income', y='spend', hue='region')
plt.title('Income vs Spend')
plt.show()

sns.scatterplot(data=df, x='age', y='spend')
plt.title('Age vs Spend')
plt.show()

# %% [markdown]
# ## 4b) Over time
#
# Nothing above uses the `date` column — and a dataset with a date almost always has
# something to say along it: a trend, a seasonal cycle, or a level shift where behaviour
# changed.
#
# This is not optional detail. Stage 09 builds lag and rolling features on exactly this
# axis, and stage 10b splits the data on it. What you find here decides what those stages
# can do — and if the rows are out of order, or there are gaps in the dates, both of
# those stages produce nonsense without telling you.

# %%
# TODO: plot at least one variable over time.
#   Hint: sort by `date` first, then set it as the index. Order matters — a rolling
#   mean computed over out-of-order rows is meaningless.

df1 = df.copy()

df1['date'] = pd.to_datetime(df1['date'])

df1 = df1.sort_values('date')

df1.set_index('date', inplace=True)

df1

fig, ax = plt.subplots(figsize=(14, 5))
ax.plot(df1.index, df1['spend'], alpha=0.6)


# TODO: check for GAPS in the dates too. A rolling window that spans a missing week is
#   not the window you think it is.
df1[df1.index.to_series().diff() > pd.Timedelta(days=1)]

# TODO: then say what you see in a markdown cell: trend, seasonality, a level shift, or
#   genuinely nothing. 'Nothing' is a real finding if you can show it.
# Out:
# Empty DataFrame
# Columns: [region, age, income, transactions, spend]
# Index: []

# %% [markdown]
# - There is no date missing in this time series and no specific trend or seasonality shif.

# %% [markdown]
# ## 5) (Optional) Correlation matrix

# %%
corr = df[['age','income','transactions','spend']].corr(numeric_only=True)
sns.heatmap(corr, annot=True, fmt='.2f', cmap='vlag', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
corr
# Out:
#                    age    income  transactions     spend
# age           1.000000 -0.123160      0.037754  0.008174
# income       -0.123160  1.000000      0.063573  0.307307
# transactions  0.037754  0.063573      1.000000  0.480685
# spend         0.008174  0.307307      0.480685  1.000000

# %% [markdown]
# ## 5b) Your reusable helper — `src/eda.py`
#
# The lecture built `eda_summary(df)` in its section 8. Copy it into `src/eda.py`, import
# it here, and call it.
#
# Stage 06 gave your project `src/cleaning.py` and stage 09 will want `src/features.py`.
# This is stage 08's contribution to the same set, and the point is that your project keeps
# ONE profiling function instead of ten pasted copies of it.

# %%
# TODO: create src/eda.py, paste the lecture's eda_summary() into it, then:
#     from src.eda import eda_summary
#     eda_summary(df)


import src.eda as eda

summary = eda.eda_summary(df)

print(summary)

# TODO (stretch): have it flag columns that need attention before stage 09 — high
#   missingness, near-zero variance, or one category dominating.
# Out:
# {'shape': (160, 6), 'dtypes': {'date': dtype('<M8[ns]'), 'region': dtype('O'), 'age': dtype('float64'), 'income': dtype('float64'), 'transactions': dtype('int32'), 'spend': dtype('float64')}, 'missing': {'date': 0, 'region': 0, 'age': 0, 'income': 5, 'transactions': 0, 'spend': 3}, 'numeric_profile':               count          mean           std       min       25%       50%  \
# age           160.0     40.018750      8.458676     22.00     34.70     40.15
# income        155.0  41983.866323  13262.457038  17928.80  32471.53  39332.52
# transactions  160.0      3.237500      2.585610      0.00      2.00      3.00
# spend         157.0    117.291592     51.768645      0.54     77.25    119.32
#
#                     75%       max      skew   kurtosis
# age              44.925     61.10  0.069538  -0.080125
# income        49697.690  87052.40  0.993336   0.918722
# transactions      4.000     20.00  3.466078  19.984802
# spend           153.340    280.05  0.130860  -0.084917  }

# %% [markdown]
# ## 6) Insights & Assumptions (write your commentary)
# - TODO: Top 3 insights
# - TODO: Assumptions & risks
# - TODO: Next steps before modeling (cleaning & features)

# %% [markdown]
# - There are 5 income data that is missing and 3 spend data that is missing. Income and Transactions data is skewed to the right. And Transactions has heavy tails which means the column has more extreme values.
# - Assume that the missing data in income and spend columns are not related and assume that the extreme values in the transactions reflect true events. There is a risk of creating bias if those assumptions are not correct.
# - Before cleaning and featuring, we should investigate the missing data and find a method to replace or remove them. We should also investigate the extreme values in the transactions column to see if there is any abnormality.

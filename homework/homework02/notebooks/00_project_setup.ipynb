# %% [markdown]
# # Environment & Config Check

# %%
import sys
sys.path.append('..')

from src.config import load_env, get_key

load_env()

# %%
# Step 5. Jupyter Check - load_dotenv()

if get_key("API_KEY"):
    print("API_KEY exists")
else:
    print("API_KEY does not exist")
# Out:
# API_KEY exists

# %%
# Step 5. Jupyter Check - run numpy and a small array op

import numpy as np

a = np.array([10, 20, 30])

print(a)
print(np.mean(a))
# Out:
# [10 20 30]
# 20.0
